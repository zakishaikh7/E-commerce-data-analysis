# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('sales.csv')
df
# Out:
#        productid      productname  productprice  customerid customername  \
# 0            110     Photo Frames           589         918         Deep
# 1            144     Office Gifts           411         918          Abc
# 2            110   Lightning Gift           100         918       Naitik
# 3            122   Lightning Gift           238         917       Naitik
# 4            115       Lippan Art          1299         918        Dhyey
# ...          ...              ...           ...         ...          ...
# 49995        110        Hoardings           416         918        Dhyey
# 49996        118  Banner Printing           680         915          Ghi
# 49997        116      Animal Toys           279         916        Dhruv
# 49998        114        Hoardings           453         917       Naitik
# 49999        113     Office Gifts           539         915        Dhyey
#
#        quantity  totalprice       area
# 0            18         820    Vadodra
# ...

# %%
df.head()
# Out:
#    productid     productname  productprice  customerid customername  quantity  \
# 0        110    Photo Frames           589         918         Deep        18
# 1        144    Office Gifts           411         918          Abc         3
# 2        110  Lightning Gift           100         918       Naitik         5
# 3        122  Lightning Gift           238         917       Naitik         2
# 4        115      Lippan Art          1299         918        Dhyey       100
#
#    totalprice       area
# 0         820    Vadodra
# 1         819  Ahmedabad
# 2        1187      Surat
# 3         885    Vadodra
# 4         500  Ahmedabad

# %%
df.tail()
# Out:
#        productid      productname  productprice  customerid customername  \
# 49995        110        Hoardings           416         918        Dhyey
# 49996        118  Banner Printing           680         915          Ghi
# 49997        116      Animal Toys           279         916        Dhruv
# 49998        114        Hoardings           453         917       Naitik
# 49999        113     Office Gifts           539         915        Dhyey
#
#        quantity  totalprice       area
# 49995        10        9640    Vadodra
# 49996         7        1183      Surat
# 49997         6        6016     Nadiad
# 49998         2         645      Surat
# 49999        16        5961  Ahmedabad

# %%
df.describe()
# Out:
#           productid  productprice    customerid      quantity    totalprice
# count  50000.000000  50000.000000  50000.000000  50000.000000  50000.000000
# mean     127.841920    485.823380    916.209440     12.379300   4200.856980
# std       16.554648    293.483161      3.179946     21.003838   5658.487106
# min      110.000000    100.000000    911.000000      2.000000    500.000000
# 25%      114.000000    300.000000    914.000000      2.000000    538.000000
# 50%      120.000000    449.000000    916.000000      4.000000   1519.000000
# 75%      143.000000    584.000000    919.000000     11.000000   5940.000000
# max      163.000000   1299.000000    922.000000    100.000000  25000.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   productid     50000 non-null  int64
#  1   productname   50000 non-null  object
#  2   productprice  50000 non-null  int64
#  3   customerid    50000 non-null  int64
#  4   customername  50000 non-null  object
#  5   quantity      50000 non-null  int64
#  6   totalprice    50000 non-null  int64
#  7   area          50000 non-null  object
# dtypes: int64(5), object(3)
# memory usage: 3.1+ MB

# %%
df.nunique()
# Out:
# productid          54
# productname        12
# productprice     1194
# customerid         12
# customername       12
# quantity           99
# totalprice      11989
# area                6
# dtype: int64

# %%
df.head()
# Out:
#    productid     productname  productprice  customerid customername  quantity  \
# 0        110    Photo Frames           589         918         Deep        18
# 1        144    Office Gifts           411         918          Abc         3
# 2        110  Lightning Gift           100         918       Naitik         5
# 3        122  Lightning Gift           238         917       Naitik         2
# 4        115      Lippan Art          1299         918        Dhyey       100
#
#    totalprice       area
# 0         820    Vadodra
# 1         819  Ahmedabad
# 2        1187      Surat
# 3         885    Vadodra
# 4         500  Ahmedabad

# %%
df['productname'].unique()
# Out:
# array(['Photo Frames', 'Office Gifts', 'Lightning Gift', 'Lippan Art',
#        'Hoardings', 'Phone Cases', 'Animal Toys', 'Sipper',
#        'Customized Bottle', 'Show Piece', 'Banner Printing',
#        'Visiting Card'], dtype=object)

# %%
df['productname'].max()
# Out:
# 'Visiting Card'

# %%
df['productname'].min()
# Out:
# 'Animal Toys'

# %%
df['productprice'].max()
# Out:
# 1299

# %%
df['productprice'].min()
# Out:
# 100

# %%
df['quantity'].max()
# Out:
# 100

# %%
df['quantity'].min()
# Out:
# 2

# %%
df['totalprice'].max()
# Out:
# 25000

# %%
df['totalprice'].min()
# Out:
# 500

# %%
import seaborn as sns
import matplotlib.pyplot as plt
fig, axs = plt.subplots(1, 3, figsize=(18, 6))
plt.subplot(131)
sns.histplot(data=df, x='productprice', bins=30, kde=True, color='g')
plt.title("Product Price")
plt.subplot(132)
sns.histplot(data=df, x='totalprice', bins=30, kde=True, color='b')
plt.title("Total Price")
plt.subplot(133)
sns.histplot(data=df, x='quantity', bins=30, kde=True, color='r')
plt.title("Quantity")
plt.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(15, 7))
plt.subplot(121)
sns.histplot(data=df,x='area',bins=30,kde=True,color='y')
plt.subplot(122)
sns.histplot(data=df,x='area',kde=True,hue='area')
plt.show()

# %%
values = df['productname'].value_counts().values
labels = df['productname'].value_counts().index
plt.figure(figsize=(10, 6))
explode = (0.1,) * len(labels) 
colors = ['red', 'green', 'blue', 'yellow', 'purple', 'orange'] 
plt.pie(values, labels=labels, autopct="%.2f%%", normalize=True, shadow=True, explode=explode, colors=colors)
legend = plt.legend(labels, loc='upper right')
legend.set_bbox_to_anchor((1.3, 1.3))
plt.title("productname")
plt.show()

# %%
values = df['area'].value_counts().values
labels = df['area'].value_counts().index
plt.figure(figsize=(10, 6))
explode = (0.1,) * len(labels) 
colors = ['red', 'green', 'blue', 'yellow', 'purple', 'orange'] 
plt.pie(values, labels=labels, autopct="%.2f%%", normalize=True, shadow=True, explode=explode, colors=colors)
legend = plt.legend(labels, loc='upper right')
legend.set_bbox_to_anchor((1.3, 1.3))
plt.title("area")
plt.show()

# %%
df['productname']=df['productname'].replace({'Photo Frames':1, 'Office Gifts':2, 'Lightning Gift':3, 'Lippan Art':4,
       'Hoardings':5, 'Phone Cases':6, 'Animal Toys':7, 'Sipper':8,
       'Customized Bottle':9, 'Show Piece':10, 'Banner Printing':11,
       'Visiting Card':12})
df
# Out:
#        productid  productname  productprice  customerid customername  \
# 0            110            1           589         918         Deep
# 1            144            2           411         918          Abc
# 2            110            3           100         918       Naitik
# 3            122            3           238         917       Naitik
# 4            115            4          1299         918        Dhyey
# ...          ...          ...           ...         ...          ...
# 49995        110            5           416         918        Dhyey
# 49996        118           11           680         915          Ghi
# 49997        116            7           279         916        Dhruv
# 49998        114            5           453         917       Naitik
# 49999        113            2           539         915        Dhyey
#
#        quantity  totalprice       area
# 0            18         820    Vadodra
# 1             3         819  Ahmedabad
# ...

# %%
from sklearn.model_selection import train_test_split
X=df['productname']
y=df['productprice']
X_train,X_test,y_train,y_test = train_test_split(X,y , test_size=0.2)

# %%
X_test_reshaped = X_test.values.reshape(-1, 1)

# %%
from sklearn import linear_model
reg=linear_model.LinearRegression()
reg.fit(X_test_reshaped,y_test)
# Out:
# LinearRegression()

# %%
reg.coef_
# Out:
# array([-3.05033416])

# %%
reg.intercept_
# Out:
# 502.3446790806965

# %%
predictions=reg.predict(X_test_reshaped)
predictions
# Out:
# array([496.24401077, 474.89167167, 474.89167167, ..., 474.89167167,
#        477.94200583, 493.19367661])

# %%
print(X_train)
print(y_train)
# Out:
# 26772    12
# 47094     3
# 10621     3
# 3051      6
# 40360    12
#          ..
# 37001     6
# 14443    10
# 8646      1
# 29790     8
# 42367     8
# Name: productname, Length: 40000, dtype: int64
# 26772    287
# 47094    418
# 10621    589
# 3051     496
# 40360    191
#         ...
# 37001    591
# 14443    457
# 8646     656
# 29790    669
# 42367    334
# Name: productprice, Length: 40000, dtype: int64
